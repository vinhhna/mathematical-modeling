# %% [markdown]
# This code is used to reconstruct the results in Figure 7, where the authors want to create a small perturbation with n_dec = 1, using κ = 1, λ = 0.1, and N = 230.

# %%
from helper_functions import plot_raster

# %%
plot_raster(N=230, n_dec=1, kappa=1, lambda_=0.1);
