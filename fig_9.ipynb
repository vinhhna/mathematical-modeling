# %% [markdown]
# This code is used to reconstruct the results in Figure 9, where the authors want to create a small perturbation with randomness, using N = 300, κ = 1, λ = 0.1, and:
# - A = 0.01
# - A = 0.05
# - A = 0.1

# %%
from helper_functions import plot_raster

# %%
plot_raster(N=300, n_dec=1, kappa=1, lambda_=0.1, noise_amplitude=0.01, simulation_time=3000);

# %%
plot_raster(N=300, n_dec=1, kappa=1, lambda_=0.1, noise_amplitude=0.05, simulation_time=3000);

# %%
plot_raster(N=300, n_dec=1, kappa=1, lambda_=0.1, noise_amplitude=0.1, simulation_time=3000);
