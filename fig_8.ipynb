# %% [markdown]
# This code is used to reconstruct the results in Figure 8 where the authors want to create a small perturbation with N = 300, and:
# - κ = 1, λ = 0.1
# - κ = 1.2, λ = 0

# %%
from helper_functions import plot_raster

# %%
plot_raster(N=300, n_dec=1, kappa=1, lambda_=0.1);

# %%
plot_raster(N=300, n_dec=1, kappa=1.2, lambda_=0);
