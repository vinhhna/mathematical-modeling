# %% [markdown]
# This code is used to reconstruct the results in Figure 6, where the authors want to create a small perturbation with n_dec = 1, using κ = 1, and λ = 0.1.

# %%
from helper_functions import plot_fundamental_diagram

# %%
plot_fundamental_diagram(kappa=1, lambda_=0.1, n_dec=1);
