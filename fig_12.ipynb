# %% [markdown]
# This code is used to reconstruct the results in Figure 12, where the authors want to create a large perturbation with n_dec = 80, using κ = 1, and λ = 0.2.

# %%
from helper_functions import plot_fundamental_diagram

# %%
plot_fundamental_diagram(kappa=1, lambda_=0.2, n_dec=80)
