# %% [markdown]
# This code is used to reconstruct the results in Figure 13, where the authors want to create a large perturbation with n_dec = 80, using κ = 1, λ = 0.2, and N = 220.

# %%
from helper_functions import plot_raster

# %%
plot_raster(N=220, n_dec=80, kappa=1, lambda_=0.2);
