# %% [markdown]
# This code is used to reconstruct the results in Figure 3, where the authors want to create a small perturbation with n_dec = 1, using κ = 1, λ = 0.5, and N = 150.

# %%
from helper_functions import plot_raster

# %%
plot_raster(N=150, n_dec=1, kappa=1, lambda_=0.5);
